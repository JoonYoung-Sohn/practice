# %% [markdown]
# <a href="https://colab.research.google.com/github/JoonYoung-Sohn/practice/blob/master/Disease%20Prediction/201222_data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2b40ab9b-e779-4de6-9450-1fbf5ba92419" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2b40ab9b-e779-4de6-9450-1fbf5ba92419">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving f_total_long.csv to f_total_long.csv

# %%
import pandas as pd
df=pd.read_csv('f_total_long.csv')
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (64) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    year        id  SEX  ...  sum_ltc_cost_ins  ltcp_kind3  service
# 0  2002  10000244    2  ...               NaN         NaN      NaN
# 1  2002  10000284    2  ...               NaN         NaN      NaN
# 2  2002  10000309    2  ...               NaN         NaN      NaN
# 3  2002  10000325    2  ...               NaN         NaN      NaN
# 4  2002  10000439    2  ...               NaN         NaN      NaN
#
# [5 rows x 71 columns]

# %%
print('열의 개수: ',len(df.columns))
print(df.columns)
# Out:
# 열의 개수:  71
# Index(['year', 'id', 'SEX', 'AGE', 'income', 'death', 'place', 'ins_type',
#        'disability', 'hospital_type', 'med_count', 'sum_med_los',
#        'sum_med_cost_tot', 'sum_med_cost_pat', 'sum_med_cost_ins',
#        'sick_count', 'LTC_MGNNU_SEQ_NO', 'score', 'grade', 'ADL_DRESS',
#        'ADL_FACEWASH', 'ADL_BRUSH', 'ADL_BATH', 'ADL_EATING', 'ADL_POSTURE',
#        'ADL_SITTING', 'ADL_TRANSFER', 'ADL_ROOMOUT', 'ADL_TOILET',
#        'ADL_S_CONTIN', 'ADL_U_CONTIN', 'ADL_SHAMPOO', 'ADL_DEPEND',
#        'ADL_COG_DEPEND', 'SHORT_MEMORY', 'TIME_ORIENT', 'PLACE_ORIENT',
#        'LONG_MEMORY', 'NO_COMMAND', 'JUDGEMENT', 'COMMUNIC', 'COUNTING',
#        'ROUTINE_AWARE', 'PERSON_ORIENT', 'BPSD_DELUSION', 'BPSD_HALLUCIN',
#        'BPSD_DEPRESS', 'BPSD_SLEEP', 'BPSD_RESIST', 'BPSD_ANXIETY',
#        'BPSD_LOST_WAY', 'BPSD_VIOLENCE', 'BPSD_TRY_OUT', 'BPSD_BREAKING',
#        'BPSD_INADE_BEHAVI', 'BPSD_HIDING', 'BPSD_INADE_DRES', 'BPSD_DIRTY',
# ...

# %%
df['year'].isnull().values.any()
# Out:
# False

# %%
year_filter = df.year >= 2008
df_after_2008 = df.loc[year_filter,:]
df_after_2008.head()
# Out:
#          year        id  SEX  ...  sum_ltc_cost_ins  ltcp_kind3  service
# 3809334  2009  10005315    2  ...               NaN         NaN      2.0
# 3809335  2009  10005315    2  ...               NaN         NaN      2.0
# 3809336  2009  10005792    1  ...         5721750.0         2.0      1.0
# 3809337  2009  10012546    2  ...        14897380.0         1.0      1.0
# 3809338  2009  10012546    2  ...        14897380.0         1.0      1.0
#
# [5 rows x 71 columns]

# %%
df_after_2008.to_csv('data_after_2008.csv', sep=',', na_rep='NaN')

# %%
from google.colab import files
files.download('data_after_2008.csv')

# %% [markdown]
# feature candidate (2008-2013)
#
# 성, 연령, 사망일자, 사망원인, 장애중증도
#
# 주상병, 부상병
#
# 신장, 체중, 허리둘레, 수축기, 이완기 혈압, 식전혈당, 총콜레스테롤, 트리글리세라이드, HDL콜레스테롤, LDL콜레스테롤, 혈색소, 요당, 요잠혈, 요PH, 요단백, 혈청크레아티닌, AST, ALT, 감마지티피, 과거력(?), 가족력(?), 흡연상태, 하루 흡연량, 과거 평균 하루 흡연량, 현재 평균 하루 흡연량, 1주 평균 음주일수, 운동횟수, 인지기능검사
