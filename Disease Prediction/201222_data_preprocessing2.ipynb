# %% [markdown]
# <a href="https://colab.research.google.com/github/JoonYoung-Sohn/practice/blob/master/Disease%20Prediction/201222_data_preprocessing2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-305c1aae-1fa1-4bb8-b50d-c52f620bf3a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-305c1aae-1fa1-4bb8-b50d-c52f620bf3a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data_after_2008.csv to data_after_2008.csv

# %%
import pandas as pd
df=pd.read_csv('data_after_2008.csv')
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (65) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  year        id  ...  sum_ltc_cost_ins  ltcp_kind3  service
# 0     3809334  2009  10005315  ...               NaN         NaN      2.0
# 1     3809335  2009  10005315  ...               NaN         NaN      2.0
# 2     3809336  2009  10005792  ...         5721750.0         2.0      1.0
# 3     3809337  2009  10012546  ...        14897380.0         1.0      1.0
# 4     3809338  2009  10012546  ...        14897380.0         1.0      1.0
#
# [5 rows x 72 columns]

# %%
df_clean = df.dropna(axis=0)

# %%
print(len(df))
print(len(df_clean))
# Out:
# 244925
# 144099

# %%
df_clean.head()
# Out:
#    Unnamed: 0  year        id  ...  sum_ltc_cost_ins  ltcp_kind3  service
# 2     3809336  2009  10005792  ...         5721750.0         2.0      1.0
# 3     3809337  2009  10012546  ...        14897380.0         1.0      1.0
# 4     3809338  2009  10012546  ...        14897380.0         1.0      1.0
# 7     3809341  2009  10024991  ...         7260890.0         2.0      1.0
# 8     3809342  2009  10028780  ...         7438930.0         2.0      1.0
#
# [5 rows x 72 columns]

# %%
df_clean.duplicated(['year', 'id'], keep='first')
# Out:
# 2         False
# 3         False
# 4          True
# 7         False
# 8         False
#           ...
# 244918    False
# 244919    False
# 244920    False
# 244922    False
# 244924    False
# Length: 144099, dtype: bool

# %%
df_clean = df_clean.drop_duplicates(['year','id'], keep='first')

# %%
print(len(df_clean))
# Out:
# 118995
